# %% [markdown]
# # Financial Distress Forecast

# %% [markdown]
# By analyzing financial client information, my aim is to determine if a specific client is likely to face bankruptcy or not.
#
# I'll employ different types of prediction models to make our forecasts.

# %%
# Data Analysis
import numpy as np
import pandas as pd

#Visualization
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
# Reducing Dimensionality using PCA
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('/content/data final.csv')

# %%
df.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# 4                                           0.522298
#
#     Operating Gross Margin   Realized Sales Gross Margin  \
# 0                 0.601457                      0.601457
# 1                 0.610235                      0.610235
# 2                 0.601450                      0.601364
# 3                 0.583541                      0.583541
# 4                 0.598783                      0.598783
#
#     Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                0.998969                    0.796887
# 1                0.998946                    0.797380
# 2                0.998857                    0.796403
# 3                0.998700                    0.796967
# 4                0.998973                    0.797366
#
#     After-tax net Interest Rate   Non-industry income and expenditure/revenue  \
# 0                      0.808809                                      0.302646
# 1                      0.809301                                      0.303556
# 2                      0.808388                                      0.302035
# 3                      0.808966                                      0.303350
# 4                      0.809304                                      0.303475
#
#    ...   Net Income to Total Assets   Total assets to GNP price  \
# 0  ...                     0.716845                    0.009219
# 1  ...                     0.795297                    0.008323
# 2  ...                     0.774670                    0.040003
# 3  ...                     0.739555                    0.003252
# 4  ...                     0.795016                    0.003878
#
#     No-credit Interval   Gross Profit to Sales  \
# 0             0.622879                0.601453
# 1             0.623652                0.610237
# 2             0.623841                0.601449
# 3             0.622929                0.583538
# 4             0.623521                0.598782
#
#     Net Income to Stockholder's Equity   Liability to Equity  \
# 0                             0.827890              0.290202
# 1                             0.839969              0.283846
# 2                             0.836774              0.290189
# 3                             0.834697              0.281721
# 4                             0.839973              0.278514
#
#     Degree of Financial Leverage (DFL)  \
# 0                             0.026601
# 1                             0.264577
# 2                             0.026555
# 3                             0.026697
# 4                             0.024752
#
#     Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 0                                           0.564050                 1.0
# 1                                           0.570175                 1.0
# 2                                           0.563706                 1.0
# 3                                           0.564663                 1.0
# 4                                           0.575617                 1.0
#
#     Equity to Liability
# 0              0.016469
# 1              0.020794
# 2              0.016474
# 3              0.023982
# 4              0.035490
#
# [5 rows x 96 columns]

# %%
df.shape
# Out:
# (2503, 96)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4377 entries, 0 to 4376
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 4377 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  4377 non-null   float64
#  2    ROA(A) before interest and % after tax                   4377 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        4377 non-null   float64
#  4    Operating Gross Margin                                   4377 non-null   float64
#  5    Realized Sales Gross Margin                              4377 non-null   float64
#  6    Operating Profit Rate                                    4377 non-null   float64
#  7    Pre-tax net Interest Rate                                4377 non-null   float64
#  8    After-tax net Interest Rate                              4377 non-null   float64
#  9    Non-industry income and expenditure/revenue              4377 non-null   float64
#  10   Continuous interest rate (after tax)                     4377 non-null   float64
#  11   Operating Expense Rate                                   4377 non-null   float64
#  12   Research and development expense rate                    4377 non-null   float64
#  13   Cash flow rate                                           4377 non-null   float64
#  14   Interest-bearing debt interest rate                      4377 non-null   float64
#  15   Tax rate (A)                                             4377 non-null   float64
#  16   Net Value Per Share (B)                                  4377 non-null   float64
#  17   Net Value Per Share (A)                                  4377 non-null   float64
#  18   Net Value Per Share (C)                                  4377 non-null   float64
#  19   Persistent EPS in the Last Four Seasons                  4377 non-null   float64
#  20   Cash Flow Per Share                                      4377 non-null   float64
#  21   Revenue Per Share (Yuan ¥)                               4377 non-null   float64
#  22   Operating Profit Per Share (Yuan ¥)                      4377 non-null   float64
#  23   Per Share Net profit before tax (Yuan ¥)                 4377 non-null   float64
#  24   Realized Sales Gross Profit Growth Rate                  4377 non-null   float64
#  25   Operating Profit Growth Rate                             4377 non-null   float64
#  26   After-tax Net Profit Growth Rate                         4377 non-null   float64
#  27   Regular Net Profit Growth Rate                           4377 non-null   float64
#  28   Continuous Net Profit Growth Rate                        4377 non-null   float64
#  29   Total Asset Growth Rate                                  4377 non-null   float64
#  30   Net Value Growth Rate                                    4377 non-null   float64
#  31   Total Asset Return Growth Rate Ratio                     4377 non-null   float64
#  32   Cash Reinvestment %                                      4377 non-null   float64
#  33   Current Ratio                                            4377 non-null   float64
#  34   Quick Ratio                                              4377 non-null   float64
#  35   Interest Expense Ratio                                   4377 non-null   float64
#  36   Total debt/Total net worth                               4377 non-null   float64
#  37   Debt ratio %                                             4377 non-null   float64
#  38   Net worth/Assets                                         4377 non-null   float64
#  39   Long-term fund suitability ratio (A)                     4377 non-null   float64
#  40   Borrowing dependency                                     4377 non-null   float64
#  41   Contingent liabilities/Net worth                         4377 non-null   float64
#  42   Operating profit/Paid-in capital                         4377 non-null   float64
#  43   Net profit before tax/Paid-in capital                    4377 non-null   float64
#  44   Inventory and accounts receivable/Net value              4377 non-null   float64
#  45   Total Asset Turnover                                     4377 non-null   float64
#  46   Accounts Receivable Turnover                             4377 non-null   float64
#  47   Average Collection Days                                  4377 non-null   float64
#  48   Inventory Turnover Rate (times)                          4377 non-null   float64
#  49   Fixed Assets Turnover Frequency                          4377 non-null   float64
#  50   Net Worth Turnover Rate (times)                          4377 non-null   float64
#  51   Revenue per person                                       4377 non-null   float64
#  52   Operating profit per person                              4377 non-null   float64
#  53   Allocation rate per person                               4377 non-null   float64
#  54   Working Capital to Total Assets                          4377 non-null   float64
#  55   Quick Assets/Total Assets                                4377 non-null   float64
#  56   Current Assets/Total Assets                              4377 non-null   float64
#  57   Cash/Total Assets                                        4377 non-null   float64
#  58   Quick Assets/Current Liability                           4376 non-null   float64
#  59   Cash/Current Liability                                   4376 non-null   float64
#  60   Current Liability to Assets                              4376 non-null   float64
#  61   Operating Funds to Liability                             4376 non-null   float64
#  62   Inventory/Working Capital                                4376 non-null   float64
#  63   Inventory/Current Liability                              4376 non-null   float64
#  64   Current Liabilities/Liability                            4376 non-null   float64
#  65   Working Capital/Equity                                   4376 non-null   float64
#  66   Current Liabilities/Equity                               4376 non-null   float64
#  67   Long-term Liability to Current Assets                    4376 non-null   float64
#  68   Retained Earnings to Total Assets                        4376 non-null   float64
#  69   Total income/Total expense                               4376 non-null   float64
#  70   Total expense/Assets                                     4376 non-null   float64
#  71   Current Asset Turnover Rate                              4376 non-null   float64
#  72   Quick Asset Turnover Rate                                4376 non-null   float64
#  73   Working capitcal Turnover Rate                           4376 non-null   float64
#  74   Cash Turnover Rate                                       4376 non-null   float64
#  75   Cash Flow to Sales                                       4376 non-null   float64
#  76   Fixed Assets to Assets                                   4376 non-null   float64
#  77   Current Liability to Liability                           4376 non-null   float64
#  78   Current Liability to Equity                              4376 non-null   float64
#  79   Equity to Long-term Liability                            4376 non-null   float64
#  80   Cash Flow to Total Assets                                4376 non-null   float64
#  81   Cash Flow to Liability                                   4376 non-null   float64
#  82   CFO to Assets                                            4376 non-null   float64
#  83   Cash Flow to Equity                                      4376 non-null   float64
#  84   Current Liability to Current Assets                      4376 non-null   float64
#  85   Liability-Assets Flag                                    4376 non-null   float64
#  86   Net Income to Total Assets                               4376 non-null   float64
#  87   Total assets to GNP price                                4376 non-null   float64
#  88   No-credit Interval                                       4376 non-null   float64
#  89   Gross Profit to Sales                                    4376 non-null   float64
#  90   Net Income to Stockholder's Equity                       4376 non-null   float64
#  91   Liability to Equity                                      4376 non-null   float64
#  92   Degree of Financial Leverage (DFL)                       4376 non-null   float64
#  93   Interest Coverage Ratio (Interest expense to EBIT)       4376 non-null   float64
#  94   Net Income Flag                                          4376 non-null   float64
#  95   Equity to Liability                                      4376 non-null   float64
# dtypes: float64(95), int64(1)
# memory usage: 3.2 MB

# %%
df.isnull().sum().sum()
# Out:
# 38

# %%
df.dropna()
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 4371          0                                           0.478770
# 4372          0                                           0.490713
# 4373          0                                           0.588310
# 4374          0                                           0.473017
# 4375          1                                           0.473212
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# 2                                    0.499019
# 3                                    0.451265
# 4                                    0.538432
# ...                                       ...
# 4371                                 0.540776
# 4372                                 0.555059
# 4373                                 0.665613
# 4374                                 0.535107
# 4375                                 0.544265
#
#        ROA(B) before interest and depreciation after tax  \
# 0                                              0.405750
# 1                                              0.516730
# 2                                              0.472295
# 3                                              0.457733
# 4                                              0.522298
# ...                                                 ...
# 4371                                           0.530596
# 4372                                           0.538787
# 4373                                           0.648911
# 4374                                           0.525349
# 4375                                           0.528508
#
#        Operating Gross Margin   Realized Sales Gross Margin  \
# 0                    0.601457                      0.601457
# 1                    0.610235                      0.610235
# 2                    0.601450                      0.601364
# 3                    0.583541                      0.583541
# 4                    0.598783                      0.598783
# ...                       ...                           ...
# 4371                 0.605558                      0.605385
# 4372                 0.598243                      0.598243
# 4373                 0.602956                      0.602956
# 4374                 0.596924                      0.596924
# 4375                 0.597746                      0.597789
#
#        Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                   0.998969                    0.796887
# 1                   0.998946                    0.797380
# 2                   0.998857                    0.796403
# 3                   0.998700                    0.796967
# 4                   0.998973                    0.797366
# ...                      ...                         ...
# 4371                0.998993                    0.797390
# 4372                0.998995                    0.797440
# 4373                0.999068                    0.797502
# 4374                0.998972                    0.797382
# 4375                0.998966                    0.797396
#
#        After-tax net Interest Rate  \
# 0                         0.808809
# 1                         0.809301
# 2                         0.808388
# 3                         0.808966
# 4                         0.809304
# ...                            ...
# 4371                      0.809320
# 4372                      0.809351
# 4373                      0.809419
# 4374                      0.809308
# 4375                      0.809326
#
#        Non-industry income and expenditure/revenue  ...  \
# 0                                         0.302646  ...
# 1                                         0.303556  ...
# 2                                         0.302035  ...
# 3                                         0.303350  ...
# 4                                         0.303475  ...
# ...                                            ...  ...
# 4371                                      0.303476  ...
# 4372                                      0.303558  ...
# 4373                                      0.303516  ...
# 4374                                      0.303504  ...
# 4375                                      0.303543  ...
#
#        Net Income to Total Assets   Total assets to GNP price  \
# 0                        0.716845                    0.009219
# 1                        0.795297                    0.008323
# 2                        0.774670                    0.040003
# 3                        0.739555                    0.003252
# 4                        0.795016                    0.003878
# ...                           ...                         ...
# 4371                     0.799734                    0.000993
# 4372                     0.809580                    0.002229
# 4373                     0.855218                    0.005578
# 4374                     0.796539                    0.001135
# 4375                     0.801594                    0.006844
#
#        No-credit Interval   Gross Profit to Sales  \
# 0                0.622879                0.601453
# 1                0.623652                0.610237
# 2                0.623841                0.601449
# 3                0.622929                0.583538
# 4                0.623521                0.598782
# ...                   ...                     ...
# 4371             0.623730                0.605553
# 4372             0.623806                0.598238
# 4373             0.624031                0.602951
# 4374             0.623362                0.596922
# 4375             0.623280                0.597742
#
#        Net Income to Stockholder's Equity   Liability to Equity  \
# 0                                0.827890              0.290202
# 1                                0.839969              0.283846
# 2                                0.836774              0.290189
# 3                                0.834697              0.281721
# 4                                0.839973              0.278514
# ...                                   ...                   ...
# 4371                             0.840351              0.279890
# 4372                             0.841298              0.281362
# 4373                             0.845571              0.281514
# 4374                             0.840113              0.285798
# 4375                             0.840520              0.280297
#
#        Degree of Financial Leverage (DFL)  \
# 0                                0.026601
# 1                                0.264577
# 2                                0.026555
# 3                                0.026697
# 4                                0.024752
# ...                                   ...
# 4371                             0.027905
# 4372                             0.026847
# 4373                             0.026792
# 4374                             0.029853
# 4375                             0.027616
#
#        Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 0                                              0.564050                 1.0
# 1                                              0.570175                 1.0
# 2                                              0.563706                 1.0
# 3                                              0.564663                 1.0
# 4                                              0.575617                 1.0
# ...                                                 ...                 ...
# 4371                                           0.567744                 1.0
# 4372                                           0.565413                 1.0
# 4373                                           0.565161                 1.0
# 4374                                           0.568904                 1.0
# 4375                                           0.567367                 1.0
#
#        Equity to Liability
# 0                 0.016469
# 1                 0.020794
# 2                 0.016474
# 3                 0.023982
# 4                 0.035490
# ...                    ...
# 4371              0.028817
# 4372              0.024722
# 4373              0.024399
# 4374              0.018940
# 4375              0.027471
#
# [4376 rows x 96 columns]

# %% [markdown]
# ## Preprocessing

# %%
def preprocess_inputs(df):
    df = df.copy()

    # Split df into X and y
    X = df.drop('Bankrupt?', axis=1)
    y = df['Bankrupt?']

    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=1)

    # Scale X
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = pd.DataFrame(scaler.transform(X_train), index=X_train.index, columns=X_train.columns)
    X_test = pd.DataFrame(scaler.transform(X_test), index=X_test.index, columns=X_test.columns)

    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = preprocess_inputs(df)

# %%
y_train
# Out:
# 1396    0
# 3979    0
# 11      0
# 3530    0
# 2662    0
#        ..
# 2895    0
# 2763    0
# 905     0
# 3980    0
# 235     1
# Name: Bankrupt?, Length: 3063, dtype: int64

# %% [markdown]
# ## Training Original Data

# %%
original_models = {
    "                   Logistic Regression": LogisticRegression(),
    "                   K-Nearest Neighbors": KNeighborsClassifier(),
    "                         Decision Tree": DecisionTreeClassifier(),
    "Support Vector Machine (Linear Kernel)": LinearSVC(),
    "   Support Vector Machine (RBF Kernel)": SVC(),
    "                        Neural Network": MLPClassifier(),
    "                         Random Forest": RandomForestClassifier(),
    "                     Gradient Boosting": GradientBoostingClassifier()
}

for name, model in original_models.items():
    model.fit(X_train, y_train)
    print(name + " trained.")

# %%
original_results = []

for name, model in original_models.items():
    result = model.score(X_test, y_test)
    original_results.append(result)
    print(name + ": {:.2f}%".format(result * 100))

# %% [markdown]
# ## Dimensionality Reduction (PCA)

# %%
n_components = 10

pca = PCA(n_components=n_components)
pca.fit(X_train)

X_train_reduced = pd.DataFrame(pca.transform(X_train), index=X_train.index, columns=["PC" + str(i) for i in range(1, n_components + 1)])
X_test_reduced = pd.DataFrame(pca.transform(X_test), index=X_test.index, columns=["PC" + str(i) for i in range(1, n_components + 1)])

# %%
X_train_reduced
# Out:
#             PC1       PC2        PC3        PC4       PC5        PC6  \
# 3392  21.396995 -7.427095 -10.383105  16.384730  8.413782  14.831841
# 2755  -0.537260 -0.632612   1.521338   0.059506 -0.896009   0.101743
# 4442  -3.777735 -0.482879   1.126984   0.334118  1.276318   0.353064
# 4267   3.117690 -0.669761   1.191446  -0.645607 -1.864045   0.641606
# 4912   0.849585  0.693085  -1.479360  -0.478790 -0.759344   0.084552
# ...         ...       ...        ...        ...       ...        ...
# 905    0.566128 -0.528644   0.117022  -0.415300  0.396887   0.989461
# 5192  -2.253184  3.498930  -4.647734  -0.693304 -0.645256   1.186563
# 3980  -5.630031  0.346380  -0.505307   1.038408  2.013045   0.596092
# 235    7.567254 -0.172185   0.268191  -0.819649 -0.230050  -0.923717
# 5157  -2.062246 -0.796847   0.953266   0.105226  0.488927   0.841177
#
#            PC7       PC8       PC9      PC10
# 3392 -1.160673  0.405999  1.807298 -2.694874
# 2755  0.173111 -0.408775 -0.434334 -0.448402
# 4442  0.874252 -0.664209 -1.483721 -1.109124
# 4267  0.852507 -0.837668 -0.099363 -1.009757
# 4912 -0.798800  0.899314  0.886556  0.631542
# ...        ...       ...       ...       ...
# 905  -0.118342 -0.664049 -0.820065 -0.265597
# 5192 -0.233703  0.482092  0.636065  0.496909
# 3980 -1.493156 -2.639506  0.489577  0.483566
# 235   2.073517  0.030414 -0.451870  0.052151
# 5157 -0.569682 -1.206482 -0.398426 -0.039571
#
# [4773 rows x 10 columns]

# %%
fig = px.bar(
    x=["PC" + str(i) for i in range(1, n_components + 1)],
    y=pca.explained_variance_ratio_,
    labels={'x': "Principal Component", 'y': "Variance Ratio"},
    color=pca.explained_variance_ratio_,
    color_continuous_scale=[(0, 'lightblue'), (1, 'darkblue')],
    title="Proportion of Variance in Principal Components"
)

fig.show()

# %% [markdown]
# ## Training the Reduced Data

# %%
reduced_models = {
    "                   Logistic Regression": LogisticRegression(),
    "                   K-Nearest Neighbors": KNeighborsClassifier(),
    "                         Decision Tree": DecisionTreeClassifier(),
    "Support Vector Machine (Linear Kernel)": LinearSVC(),
    "   Support Vector Machine (RBF Kernel)": SVC(),
    "                        Neural Network": MLPClassifier(),
    "                         Random Forest": RandomForestClassifier(),
    "                     Gradient Boosting": GradientBoostingClassifier()
}

for name, model in reduced_models.items():
    model.fit(X_train_reduced, y_train)
    print(name + " trained.")
# Out:
#                    Logistic Regression trained.
#                    K-Nearest Neighbors trained.
#                          Decision Tree trained.
# C:\Users\user.DESKTOP-OMQ89VA\miniconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning:
#
# Liblinear failed to converge, increase the number of iterations.
# Support Vector Machine (Linear Kernel) trained.
#    Support Vector Machine (RBF Kernel) trained.
# C:\Users\user.DESKTOP-OMQ89VA\miniconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:702: ConvergenceWarning:
#
# Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#                         Neural Network trained.
#                          Random Forest trained.
#                      Gradient Boosting trained.

# %%
reduced_results = []

for name, model in reduced_models.items():
    result = model.score(X_test_reduced, y_test)
    reduced_results.append(result)
    print(name + ": {:.2f}%".format(result * 100))
# Out:
#                    Logistic Regression: 96.24%
#                    K-Nearest Neighbors: 96.33%
#                          Decision Tree: 94.72%
# Support Vector Machine (Linear Kernel): 96.43%
#    Support Vector Machine (RBF Kernel): 96.63%
#                         Neural Network: 96.43%
#                          Random Forest: 96.48%
#                      Gradient Boosting: 96.24%

# %% [markdown]
# ## Performance Change After PCA

# %%
fig = px.bar(
    x=np.subtract(reduced_results, original_results),
    y=original_models.keys(),
    orientation='h',
    labels={'x': "Change in Performance", 'y': "Model"},
    color=np.subtract(reduced_results, original_results),
    color_continuous_scale=[(0, 'red'), (1, 'blue')],
    title="Change in Model Performance After Dimensionality Reduction"
)

fig.show()

# %% [markdown]
# Based on the results obtained, it can be concluded that the Support Vector Machine (RBF kernel) has the best performance with an accuracy of 96.63%.
#
# The other models such as Logistic Regression, K-Nearest Neighbors, Support Vector Machine (Linear kernel), and Neural Network also perform well with an accuracy of 96.24-96.43%.
#
# The Decision Tree model performs comparatively poorly with an accuracy of 94.72%.
#
# The Random Forest and Gradient Boosting models also have similar performance with an accuracy of 96.48% and 96.24%, respectively.
#
# #### These results demonstrate the effectiveness of using machine learning algorithms for the task of bankruptcy prediction.
